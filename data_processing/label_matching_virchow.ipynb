# %% [markdown]
# ## Look at the h5 files

# %%
# %pwd
# %cd ..
# %pwd
# Out:
# /orcd/data/edboyden/002/ezh/uni
# /home/ezh/.conda/envs/clam_latest/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/orcd/data/edboyden/002/ezh/uni'

# %%
import h5py

with h5py.File("/orcd/data/edboyden/002/ezh/uni/virchow_features/TCGA-3L-AA1B.h5", "r") as f:
    print(list(f.keys()))
    print(f["features"].shape)  # (N_patches, 1536)
    if "KRAS_binary" in f:
        print(f["KRAS_binary"][()])
# Out:
# ['HER2_Amp', 'KRAS_binary', 'Lymphovascular invasion indicator', 'coords', 'features', 'mmr_status']
# (8988, 2560)
# 0

# %% [markdown]
# ## Match each h5 file to label

# %%
import pandas as pd

# Load the file
mutation_df = pd.read_csv('/orcd/data/edboyden/002/ezh/uni/datasets/kras_labels.csv')

display(mutation_df.head(10))
# Out:
#    index     Sample_ID  KRAS  KRAS_binary
# 0      0  TCGA-3L-AA1B    WT          0.0
# 1      1  TCGA-4N-A93T  G12D          1.0
# 2      2  TCGA-4T-AA8H  G12V          1.0
# 3      3  TCGA-5M-AAT4  G12D          1.0
# 4      4  TCGA-5M-AAT5  G12D          1.0
# 5      5  TCGA-5M-AAT6  G12D          1.0
# 6      6  TCGA-5M-AATA    WT          0.0
# 7      7  TCGA-5M-AATE  G13D          1.0
# 8      8  TCGA-A6-2670    WT          0.0
# 9      9  TCGA-A6-2671    WT          0.0

# %%
import os
import pandas as pd
from glob import glob

# %%
h5_folder = "/orcd/data/edboyden/002/ezh/uni/virchow_features"
mutation = "KRAS_binary"
h5_paths = sorted(glob(os.path.join(h5_folder, "*.h5")))
print(f"\nFound {len(h5_paths)} .h5 files")
# Out:
# Found 493 .h5 files

# %%
# Extract TCGA ID from each .h5 filename
def extract_tcga_id(path):
    basename = os.path.basename(path)
    return "-".join(basename.split("-")[:3])  # TCGA-XX-YYYY

h5_df = pd.DataFrame({
    "h5_path": h5_paths,
    "Sample_ID": [extract_tcga_id(p) for p in h5_paths]
})

h5_df['Sample_ID'] = h5_df['Sample_ID'].str.replace('.h5', '')

print("\nFirst 5 extracted TCGA IDs:")
print(h5_df.head())
# Out:
# First 5 extracted TCGA IDs:
#                                              h5_path     Sample_ID
# 0  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-3L-AA1B
# 1  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4N-A93T
# 2  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4T-AA8H
# 3  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT4
# 4  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT5

# %%
print("\nSample_ID format in mutation_df:")
print(mutation_df['Sample_ID'].head())

print("\nSample_ID format in h5_df:")
print(h5_df['Sample_ID'].head())
# Out:
# Sample_ID format in mutation_df:
# 0    TCGA-3L-AA1B
# 1    TCGA-4N-A93T
# 2    TCGA-4T-AA8H
# 3    TCGA-5M-AAT4
# 4    TCGA-5M-AAT5
# Name: Sample_ID, dtype: object
#
# Sample_ID format in h5_df:
# 0    TCGA-3L-AA1B
# 1    TCGA-4N-A93T
# 2    TCGA-4T-AA8H
# 3    TCGA-5M-AAT4
# 4    TCGA-5M-AAT5
# Name: Sample_ID, dtype: object

# %%
merged_df = h5_df.merge(mutation_df, on="Sample_ID", how="left")

display(merged_df.head(10))

# Separate matched/unmatched again
matched = merged_df.dropna(subset=[mutation])
unmatched = merged_df[merged_df[mutation].isna()]

# Print results
print(f"\nMatched: {len(matched)}")
print(f"Unmatched: {len(unmatched)}")
print("\nMatched sample preview:")
print(matched[["Sample_ID", mutation]].head(5))
# Out:
#                                              h5_path     Sample_ID  index  \
# 0  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-3L-AA1B      0
# 1  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4N-A93T      1
# 2  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4T-AA8H      2
# 3  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT4      3
# 4  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT5      4
# 5  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT6      5
# 6  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AATE      7
# 7  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-A6-2671      9
# 8  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-A6-2672     10
# 9  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-A6-2674     11
#
#    KRAS  KRAS_binary
# 0    WT          0.0
# 1  G12D          1.0
# 2  G12V          1.0
# 3  G12D          1.0
# 4  G12D          1.0
# 5  G12D          1.0
# 6  G13D          1.0
# 7    WT          0.0
# 8    WT          0.0
# 9    WT          0.0
# Matched: 490
# Unmatched: 3
#
# Matched sample preview:
#       Sample_ID  KRAS_binary
# 0  TCGA-3L-AA1B          0.0
# 1  TCGA-4N-A93T          1.0
# 2  TCGA-4T-AA8H          1.0
# 3  TCGA-5M-AAT4          1.0
# 4  TCGA-5M-AAT5          1.0

# %%
print(matched[mutation].value_counts())
# Out:
# KRAS_binary
# 0.0    295
# 1.0    195
# Name: count, dtype: int64

# %% [markdown]
# ### Save the mutation status column in the h5 file

# %%
import h5py

# Loop over matched rows
for idx, row in matched.iterrows():
    h5_path = row["h5_path"]
    label = int(row[mutation])  # make sure it's a simple 0 or 1
    
    try:
        with h5py.File(h5_path, "a") as f:  # 'a' = append mode
            if mutation in f:
                print(f"Overwriting existing {mutation} in {os.path.basename(h5_path)}")
                del f[mutation]
            else:
                print(f"Writing {mutation} to {os.path.basename(h5_path)}")
            
            f.create_dataset(mutation, data=label)
    
    except Exception as e:
        print(f"Error writing to {h5_path}: {e}")
# Out:
# Writing KRAS_binary to TCGA-3L-AA1B.h5
# Writing KRAS_binary to TCGA-4N-A93T.h5
# Writing KRAS_binary to TCGA-4T-AA8H.h5
# Writing KRAS_binary to TCGA-5M-AAT4.h5
# Writing KRAS_binary to TCGA-5M-AAT5.h5
# Writing KRAS_binary to TCGA-5M-AAT6.h5
# Writing KRAS_binary to TCGA-5M-AATE.h5
# Writing KRAS_binary to TCGA-A6-2671.h5
# Writing KRAS_binary to TCGA-A6-2672.h5
# Writing KRAS_binary to TCGA-A6-2674.h5
# Writing KRAS_binary to TCGA-A6-2675.h5
# Writing KRAS_binary to TCGA-A6-2676.h5
# Writing KRAS_binary to TCGA-A6-2677.h5
# Writing KRAS_binary to TCGA-A6-2678.h5
# Writing KRAS_binary to TCGA-A6-2679.h5
# Writing KRAS_binary to TCGA-A6-2680.h5
# Writing KRAS_binary to TCGA-A6-2681.h5
# Writing KRAS_binary to TCGA-A6-2682.h5
# Writing KRAS_binary to TCGA-A6-2683.h5
# Writing KRAS_binary to TCGA-A6-2684.h5
# Writing KRAS_binary to TCGA-A6-2685.h5
# Writing KRAS_binary to TCGA-A6-2686.h5
# Writing KRAS_binary to TCGA-A6-3807.h5
# Writing KRAS_binary to TCGA-A6-3808.h5
# Writing KRAS_binary to TCGA-A6-3809.h5
# Writing KRAS_binary to TCGA-A6-3810.h5
# Writing KRAS_binary to TCGA-A6-4105.h5
# Writing KRAS_binary to TCGA-A6-4107.h5
# Writing KRAS_binary to TCGA-A6-5656.h5
# Writing KRAS_binary to TCGA-A6-5657.h5
# Writing KRAS_binary to TCGA-A6-5659.h5
# Writing KRAS_binary to TCGA-A6-5660.h5
# Writing KRAS_binary to TCGA-A6-5661.h5
# Writing KRAS_binary to TCGA-A6-5662.h5
# Writing KRAS_binary to TCGA-A6-5664.h5
# Writing KRAS_binary to TCGA-A6-5665.h5
# Writing KRAS_binary to TCGA-A6-5666.h5
# Writing KRAS_binary to TCGA-A6-5667.h5
# Writing KRAS_binary to TCGA-A6-6137.h5
# Writing KRAS_binary to TCGA-A6-6138.h5
# Writing KRAS_binary to TCGA-A6-6142.h5
# Writing KRAS_binary to TCGA-A6-6648.h5
# Writing KRAS_binary to TCGA-A6-6649.h5
# Writing KRAS_binary to TCGA-A6-6650.h5
# Writing KRAS_binary to TCGA-A6-6651.h5
# Writing KRAS_binary to TCGA-A6-6652.h5
# Writing KRAS_binary to TCGA-A6-6653.h5
# Writing KRAS_binary to TCGA-A6-6654.h5
# Writing KRAS_binary to TCGA-A6-A565.h5
# Writing KRAS_binary to TCGA-A6-A566.h5
# Writing KRAS_binary to TCGA-A6-A567.h5
# Writing KRAS_binary to TCGA-A6-A56B.h5
# Writing KRAS_binary to TCGA-A6-A5ZU.h5
# Writing KRAS_binary to TCGA-AA-3488.h5
# Writing KRAS_binary to TCGA-AA-3489.h5
# Writing KRAS_binary to TCGA-AA-3492.h5
# Writing KRAS_binary to TCGA-AA-3494.h5
# Writing KRAS_binary to TCGA-AA-3495.h5
# Writing KRAS_binary to TCGA-AA-3496.h5
# Writing KRAS_binary to TCGA-AA-3506.h5
# Writing KRAS_binary to TCGA-AA-3509.h5
# Writing KRAS_binary to TCGA-AA-3510.h5
# Writing KRAS_binary to TCGA-AA-3511.h5
# Writing KRAS_binary to TCGA-AA-3514.h5
# Writing KRAS_binary to TCGA-AA-3516.h5
# Writing KRAS_binary to TCGA-AA-3517.h5
# Writing KRAS_binary to TCGA-AA-3518.h5
# Writing KRAS_binary to TCGA-AA-3519.h5
# Writing KRAS_binary to TCGA-AA-3520.h5
# Writing KRAS_binary to TCGA-AA-3521.h5
# Writing KRAS_binary to TCGA-AA-3522.h5
# Writing KRAS_binary to TCGA-AA-3524.h5
# Writing KRAS_binary to TCGA-AA-3525.h5
# Writing KRAS_binary to TCGA-AA-3526.h5
# Writing KRAS_binary to TCGA-AA-3527.h5
# Writing KRAS_binary to TCGA-AA-3529.h5
# Writing KRAS_binary to TCGA-AA-3530.h5
# Writing KRAS_binary to TCGA-AA-3531.h5
# Writing KRAS_binary to TCGA-AA-3532.h5
# Writing KRAS_binary to TCGA-AA-3534.h5
# Writing KRAS_binary to TCGA-AA-3538.h5
# Writing KRAS_binary to TCGA-AA-3542.h5
# Writing KRAS_binary to TCGA-AA-3543.h5
# Writing KRAS_binary to TCGA-AA-3544.h5
# Writing KRAS_binary to TCGA-AA-3548.h5
# Writing KRAS_binary to TCGA-AA-3549.h5
# Writing KRAS_binary to TCGA-AA-3552.h5
# Writing KRAS_binary to TCGA-AA-3553.h5
# Writing KRAS_binary to TCGA-AA-3554.h5
# Writing KRAS_binary to TCGA-AA-3555.h5
# Writing KRAS_binary to TCGA-AA-3556.h5
# Writing KRAS_binary to TCGA-AA-3558.h5
# Writing KRAS_binary to TCGA-AA-3560.h5
# Writing KRAS_binary to TCGA-AA-3561.h5
# Writing KRAS_binary to TCGA-AA-3562.h5
# Writing KRAS_binary to TCGA-AA-3655.h5
# Writing KRAS_binary to TCGA-AA-3660.h5
# Writing KRAS_binary to TCGA-AA-3662.h5
# Writing KRAS_binary to TCGA-AA-3663.h5
# Writing KRAS_binary to TCGA-AA-3664.h5
# Writing KRAS_binary to TCGA-AA-3666.h5
# Writing KRAS_binary to TCGA-AA-3667.h5
# Writing KRAS_binary to TCGA-AA-3672.h5
# Writing KRAS_binary to TCGA-AA-3673.h5
# Writing KRAS_binary to TCGA-AA-3675.h5
# Writing KRAS_binary to TCGA-AA-3678.h5
# Writing KRAS_binary to TCGA-AA-3679.h5
# Writing KRAS_binary to TCGA-AA-3680.h5
# Writing KRAS_binary to TCGA-AA-3681.h5
# Writing KRAS_binary to TCGA-AA-3684.h5
# Writing KRAS_binary to TCGA-AA-3685.h5
# Writing KRAS_binary to TCGA-AA-3688.h5
# Writing KRAS_binary to TCGA-AA-3692.h5
# Writing KRAS_binary to TCGA-AA-3693.h5
# Writing KRAS_binary to TCGA-AA-3695.h5
# Writing KRAS_binary to TCGA-AA-3696.h5
# Writing KRAS_binary to TCGA-AA-3697.h5
# Writing KRAS_binary to TCGA-AA-3710.h5
# Writing KRAS_binary to TCGA-AA-3712.h5
# Writing KRAS_binary to TCGA-AA-3713.h5
# Writing KRAS_binary to TCGA-AA-3715.h5
# Writing KRAS_binary to TCGA-AA-3811.h5
# Writing KRAS_binary to TCGA-AA-3812.h5
# Writing KRAS_binary to TCGA-AA-3814.h5
# Writing KRAS_binary to TCGA-AA-3815.h5
# Writing KRAS_binary to TCGA-AA-3818.h5
# Writing KRAS_binary to TCGA-AA-3819.h5
# Writing KRAS_binary to TCGA-AA-3821.h5
# Writing KRAS_binary to TCGA-AA-3831.h5
# Writing KRAS_binary to TCGA-AA-3833.h5
# Writing KRAS_binary to TCGA-AA-3837.h5
# Writing KRAS_binary to TCGA-AA-3841.h5
# Writing KRAS_binary to TCGA-AA-3842.h5
# Writing KRAS_binary to TCGA-AA-3844.h5
# Writing KRAS_binary to TCGA-AA-3845.h5
# Writing KRAS_binary to TCGA-AA-3846.h5
# Writing KRAS_binary to TCGA-AA-3848.h5
# Writing KRAS_binary to TCGA-AA-3850.h5
# Writing KRAS_binary to TCGA-AA-3851.h5
# Writing KRAS_binary to TCGA-AA-3852.h5
# Writing KRAS_binary to TCGA-AA-3854.h5
# Writing KRAS_binary to TCGA-AA-3855.h5
# Writing KRAS_binary to TCGA-AA-3856.h5
# Writing KRAS_binary to TCGA-AA-3858.h5
# Writing KRAS_binary to TCGA-AA-3860.h5
# Writing KRAS_binary to TCGA-AA-3861.h5
# Writing KRAS_binary to TCGA-AA-3862.h5
# Writing KRAS_binary to TCGA-AA-3864.h5
# Writing KRAS_binary to TCGA-AA-3866.h5
# Writing KRAS_binary to TCGA-AA-3867.h5
# Writing KRAS_binary to TCGA-AA-3869.h5
# Writing KRAS_binary to TCGA-AA-3870.h5
# Writing KRAS_binary to TCGA-AA-3872.h5
# Writing KRAS_binary to TCGA-AA-3875.h5
# Writing KRAS_binary to TCGA-AA-3877.h5
# Writing KRAS_binary to TCGA-AA-3930.h5
# Writing KRAS_binary to TCGA-AA-3939.h5
# Writing KRAS_binary to TCGA-AA-3941.h5
# Writing KRAS_binary to TCGA-AA-3947.h5
# Writing KRAS_binary to TCGA-AA-3949.h5
# Writing KRAS_binary to TCGA-AA-3950.h5
# Writing KRAS_binary to TCGA-AA-3952.h5
# Writing KRAS_binary to TCGA-AA-3955.h5
# Writing KRAS_binary to TCGA-AA-3956.h5
# Writing KRAS_binary to TCGA-AA-3966.h5
# Writing KRAS_binary to TCGA-AA-3967.h5
# Writing KRAS_binary to TCGA-AA-3968.h5
# Writing KRAS_binary to TCGA-AA-3971.h5
# Writing KRAS_binary to TCGA-AA-3972.h5
# Writing KRAS_binary to TCGA-AA-3973.h5
# Writing KRAS_binary to TCGA-AA-3975.h5
# Writing KRAS_binary to TCGA-AA-3976.h5
# Writing KRAS_binary to TCGA-AA-3977.h5
# Writing KRAS_binary to TCGA-AA-3979.h5
# Writing KRAS_binary to TCGA-AA-3980.h5
# Writing KRAS_binary to TCGA-AA-3982.h5
# Writing KRAS_binary to TCGA-AA-3984.h5
# Writing KRAS_binary to TCGA-AA-3986.h5
# Writing KRAS_binary to TCGA-AA-3989.h5
# Writing KRAS_binary to TCGA-AA-3994.h5
# Writing KRAS_binary to TCGA-AA-A004.h5
# Writing KRAS_binary to TCGA-AA-A00A.h5
# Writing KRAS_binary to TCGA-AA-A00D.h5
# Writing KRAS_binary to TCGA-AA-A00E.h5
# Writing KRAS_binary to TCGA-AA-A00F.h5
# Writing KRAS_binary to TCGA-AA-A00J.h5
# Writing KRAS_binary to TCGA-AA-A00K.h5
# Writing KRAS_binary to TCGA-AA-A00L.h5
# Writing KRAS_binary to TCGA-AA-A00N.h5
# Writing KRAS_binary to TCGA-AA-A00O.h5
# Writing KRAS_binary to TCGA-AA-A00Q.h5
# Writing KRAS_binary to TCGA-AA-A00R.h5
# Writing KRAS_binary to TCGA-AA-A00U.h5
# Writing KRAS_binary to TCGA-AA-A00W.h5
# Writing KRAS_binary to TCGA-AA-A00Z.h5
# Writing KRAS_binary to TCGA-AA-A010.h5
# Writing KRAS_binary to TCGA-AA-A017.h5
# Writing KRAS_binary to TCGA-AA-A01C.h5
# Writing KRAS_binary to TCGA-AA-A01D.h5
# Writing KRAS_binary to TCGA-AA-A01F.h5
# Writing KRAS_binary to TCGA-AA-A01G.h5
# Writing KRAS_binary to TCGA-AA-A01I.h5
# Writing KRAS_binary to TCGA-AA-A01K.h5
# Writing KRAS_binary to TCGA-AA-A01P.h5
# Writing KRAS_binary to TCGA-AA-A01Q.h5
# Writing KRAS_binary to TCGA-AA-A01R.h5
# Writing KRAS_binary to TCGA-AA-A01S.h5
# Writing KRAS_binary to TCGA-AA-A01T.h5
# Writing KRAS_binary to TCGA-AA-A01V.h5
# Writing KRAS_binary to TCGA-AA-A01X.h5
# Writing KRAS_binary to TCGA-AA-A01Z.h5
# Writing KRAS_binary to TCGA-AA-A022.h5
# Writing KRAS_binary to TCGA-AA-A024.h5
# Writing KRAS_binary to TCGA-AA-A029.h5
# Writing KRAS_binary to TCGA-AA-A02E.h5
# Writing KRAS_binary to TCGA-AA-A02F.h5
# Writing KRAS_binary to TCGA-AA-A02H.h5
# Writing KRAS_binary to TCGA-AA-A02J.h5
# Writing KRAS_binary to TCGA-AA-A02K.h5
# Writing KRAS_binary to TCGA-AA-A02O.h5
# Writing KRAS_binary to TCGA-AA-A02R.h5
# Writing KRAS_binary to TCGA-AA-A02W.h5
# Writing KRAS_binary to TCGA-AA-A02Y.h5
# Writing KRAS_binary to TCGA-AA-A03F.h5
# Writing KRAS_binary to TCGA-AA-A03J.h5
# Writing KRAS_binary to TCGA-AD-5900.h5
# Writing KRAS_binary to TCGA-AD-6548.h5
# Writing KRAS_binary to TCGA-AD-6888.h5
# Writing KRAS_binary to TCGA-AD-6889.h5
# Writing KRAS_binary to TCGA-AD-6890.h5
# Writing KRAS_binary to TCGA-AD-6895.h5
# Writing KRAS_binary to TCGA-AD-6899.h5
# Writing KRAS_binary to TCGA-AD-6901.h5
# Writing KRAS_binary to TCGA-AD-6963.h5
# Writing KRAS_binary to TCGA-AD-6964.h5
# Writing KRAS_binary to TCGA-AD-6965.h5
# Writing KRAS_binary to TCGA-AD-A5EJ.h5
# Writing KRAS_binary to TCGA-AD-A5EK.h5
# Writing KRAS_binary to TCGA-AF-2687.h5
# Writing KRAS_binary to TCGA-AF-2690.h5
# Writing KRAS_binary to TCGA-AF-2693.h5
# Writing KRAS_binary to TCGA-AF-3911.h5
# Writing KRAS_binary to TCGA-AF-4110.h5
# Writing KRAS_binary to TCGA-AF-5654.h5
# Writing KRAS_binary to TCGA-AF-6136.h5
# Writing KRAS_binary to TCGA-AF-6655.h5
# Writing KRAS_binary to TCGA-AF-6672.h5
# Writing KRAS_binary to TCGA-AF-A56K.h5
# Writing KRAS_binary to TCGA-AF-A56L.h5
# Writing KRAS_binary to TCGA-AF-A56N.h5
# Writing KRAS_binary to TCGA-AG-3591.h5
# Writing KRAS_binary to TCGA-AG-3592.h5
# Writing KRAS_binary to TCGA-AG-3725.h5
# Writing KRAS_binary to TCGA-AG-3731.h5
# Writing KRAS_binary to TCGA-AG-3732.h5
# Writing KRAS_binary to TCGA-AG-3742.h5
# Writing KRAS_binary to TCGA-AG-3902.h5
# Writing KRAS_binary to TCGA-AG-4021.h5
# Writing KRAS_binary to TCGA-AG-4022.h5
# Writing KRAS_binary to TCGA-AH-6544.h5
# Writing KRAS_binary to TCGA-AH-6547.h5
# Writing KRAS_binary to TCGA-AH-6643.h5
# Writing KRAS_binary to TCGA-AH-6644.h5
# Writing KRAS_binary to TCGA-AH-6897.h5
# Writing KRAS_binary to TCGA-AH-6903.h5
# Writing KRAS_binary to TCGA-AM-5820.h5
# Writing KRAS_binary to TCGA-AM-5821.h5
# Writing KRAS_binary to TCGA-AU-3779.h5
# Writing KRAS_binary to TCGA-AU-6004.h5
# Writing KRAS_binary to TCGA-AY-4070.h5
# Writing KRAS_binary to TCGA-AY-4071.h5
# Writing KRAS_binary to TCGA-AY-5543.h5
# Writing KRAS_binary to TCGA-AY-6196.h5
# Writing KRAS_binary to TCGA-AY-6197.h5
# Writing KRAS_binary to TCGA-AY-6386.h5
# Writing KRAS_binary to TCGA-AY-A54L.h5
# Writing KRAS_binary to TCGA-AY-A69D.h5
# Writing KRAS_binary to TCGA-AY-A71X.h5
# Writing KRAS_binary to TCGA-AY-A8YK.h5
# Writing KRAS_binary to TCGA-AZ-4308.h5
# Writing KRAS_binary to TCGA-AZ-4313.h5
# Writing KRAS_binary to TCGA-AZ-4315.h5
# Writing KRAS_binary to TCGA-AZ-4614.h5
# Writing KRAS_binary to TCGA-AZ-4615.h5
# Writing KRAS_binary to TCGA-AZ-4616.h5
# Writing KRAS_binary to TCGA-AZ-4681.h5
# Writing KRAS_binary to TCGA-AZ-4682.h5
# Writing KRAS_binary to TCGA-AZ-4684.h5
# Writing KRAS_binary to TCGA-CK-4952.h5
# Writing KRAS_binary to TCGA-CK-5912.h5
# Writing KRAS_binary to TCGA-CK-5913.h5
# Writing KRAS_binary to TCGA-CK-5914.h5
# Writing KRAS_binary to TCGA-CK-5915.h5
# Writing KRAS_binary to TCGA-CK-5916.h5
# Writing KRAS_binary to TCGA-CK-6746.h5
# Writing KRAS_binary to TCGA-CK-6747.h5
# Writing KRAS_binary to TCGA-CK-6748.h5
# Writing KRAS_binary to TCGA-CK-6751.h5
# Writing KRAS_binary to TCGA-CL-4957.h5
# Writing KRAS_binary to TCGA-CL-5917.h5
# Writing KRAS_binary to TCGA-CL-5918.h5
# Writing KRAS_binary to TCGA-CM-4743.h5
# Writing KRAS_binary to TCGA-CM-4744.h5
# Writing KRAS_binary to TCGA-CM-4746.h5
# Writing KRAS_binary to TCGA-CM-4747.h5
# Writing KRAS_binary to TCGA-CM-4748.h5
# Writing KRAS_binary to TCGA-CM-4750.h5
# Writing KRAS_binary to TCGA-CM-4751.h5
# Writing KRAS_binary to TCGA-CM-4752.h5
# Writing KRAS_binary to TCGA-CM-5341.h5
# Writing KRAS_binary to TCGA-CM-5344.h5
# Writing KRAS_binary to TCGA-CM-5348.h5
# Writing KRAS_binary to TCGA-CM-5349.h5
# Writing KRAS_binary to TCGA-CM-5860.h5
# Writing KRAS_binary to TCGA-CM-5861.h5
# Writing KRAS_binary to TCGA-CM-5862.h5
# Writing KRAS_binary to TCGA-CM-5863.h5
# Writing KRAS_binary to TCGA-CM-5864.h5
# Writing KRAS_binary to TCGA-CM-5868.h5
# Writing KRAS_binary to TCGA-CM-6161.h5
# Writing KRAS_binary to TCGA-CM-6162.h5
# Writing KRAS_binary to TCGA-CM-6163.h5
# Writing KRAS_binary to TCGA-CM-6164.h5
# Writing KRAS_binary to TCGA-CM-6165.h5
# Writing KRAS_binary to TCGA-CM-6166.h5
# Writing KRAS_binary to TCGA-CM-6167.h5
# Writing KRAS_binary to TCGA-CM-6168.h5
# Writing KRAS_binary to TCGA-CM-6169.h5
# Writing KRAS_binary to TCGA-CM-6170.h5
# Writing KRAS_binary to TCGA-CM-6171.h5
# Writing KRAS_binary to TCGA-CM-6172.h5
# Writing KRAS_binary to TCGA-CM-6674.h5
# Writing KRAS_binary to TCGA-CM-6675.h5
# Writing KRAS_binary to TCGA-CM-6676.h5
# Writing KRAS_binary to TCGA-CM-6677.h5
# Writing KRAS_binary to TCGA-CM-6678.h5
# Writing KRAS_binary to TCGA-CM-6679.h5
# Writing KRAS_binary to TCGA-CM-6680.h5
# Writing KRAS_binary to TCGA-D5-5537.h5
# Writing KRAS_binary to TCGA-D5-5538.h5
# Writing KRAS_binary to TCGA-D5-5539.h5
# Writing KRAS_binary to TCGA-D5-5540.h5
# Writing KRAS_binary to TCGA-D5-5541.h5
# Writing KRAS_binary to TCGA-D5-6529.h5
# Writing KRAS_binary to TCGA-D5-6530.h5
# Writing KRAS_binary to TCGA-D5-6531.h5
# Writing KRAS_binary to TCGA-D5-6532.h5
# Writing KRAS_binary to TCGA-D5-6533.h5
# Writing KRAS_binary to TCGA-D5-6534.h5
# Writing KRAS_binary to TCGA-D5-6535.h5
# Writing KRAS_binary to TCGA-D5-6536.h5
# Writing KRAS_binary to TCGA-D5-6537.h5
# Writing KRAS_binary to TCGA-D5-6538.h5
# Writing KRAS_binary to TCGA-D5-6539.h5
# Writing KRAS_binary to TCGA-D5-6540.h5
# Writing KRAS_binary to TCGA-D5-6541.h5
# Writing KRAS_binary to TCGA-D5-6898.h5
# Writing KRAS_binary to TCGA-D5-6920.h5
# Writing KRAS_binary to TCGA-D5-6922.h5
# Writing KRAS_binary to TCGA-D5-6923.h5
# Writing KRAS_binary to TCGA-D5-6924.h5
# Writing KRAS_binary to TCGA-D5-6926.h5
# Writing KRAS_binary to TCGA-D5-6927.h5
# Writing KRAS_binary to TCGA-D5-6928.h5
# Writing KRAS_binary to TCGA-D5-6929.h5
# Writing KRAS_binary to TCGA-D5-6930.h5
# Writing KRAS_binary to TCGA-D5-6931.h5
# Writing KRAS_binary to TCGA-D5-6932.h5
# Writing KRAS_binary to TCGA-D5-7000.h5
# Writing KRAS_binary to TCGA-DC-4745.h5
# Writing KRAS_binary to TCGA-DC-4749.h5
# Writing KRAS_binary to TCGA-DC-5337.h5
# Writing KRAS_binary to TCGA-DC-5869.h5
# Writing KRAS_binary to TCGA-DC-6154.h5
# Writing KRAS_binary to TCGA-DC-6155.h5
# Writing KRAS_binary to TCGA-DC-6156.h5
# Writing KRAS_binary to TCGA-DC-6157.h5
# Writing KRAS_binary to TCGA-DC-6158.h5
# Writing KRAS_binary to TCGA-DC-6160.h5
# Writing KRAS_binary to TCGA-DC-6681.h5
# Writing KRAS_binary to TCGA-DC-6682.h5
# Writing KRAS_binary to TCGA-DC-6683.h5
# Writing KRAS_binary to TCGA-DM-A0X9.h5
# Writing KRAS_binary to TCGA-DM-A0XD.h5
# Writing KRAS_binary to TCGA-DM-A0XF.h5
# Writing KRAS_binary to TCGA-DM-A1D0.h5
# Writing KRAS_binary to TCGA-DM-A1D4.h5
# Writing KRAS_binary to TCGA-DM-A1D6.h5
# Writing KRAS_binary to TCGA-DM-A1D7.h5
# Writing KRAS_binary to TCGA-DM-A1D8.h5
# Writing KRAS_binary to TCGA-DM-A1D9.h5
# Writing KRAS_binary to TCGA-DM-A1DA.h5
# Writing KRAS_binary to TCGA-DM-A1DB.h5
# Writing KRAS_binary to TCGA-DM-A1HA.h5
# Writing KRAS_binary to TCGA-DM-A280.h5
# Writing KRAS_binary to TCGA-DM-A282.h5
# Writing KRAS_binary to TCGA-DM-A285.h5
# Writing KRAS_binary to TCGA-DM-A288.h5
# Writing KRAS_binary to TCGA-DM-A28A.h5
# Writing KRAS_binary to TCGA-DM-A28E.h5
# Writing KRAS_binary to TCGA-DM-A28F.h5
# Writing KRAS_binary to TCGA-DM-A28G.h5
# Writing KRAS_binary to TCGA-DM-A28H.h5
# Writing KRAS_binary to TCGA-DM-A28K.h5
# Writing KRAS_binary to TCGA-DM-A28M.h5
# Writing KRAS_binary to TCGA-DT-5265.h5
# Writing KRAS_binary to TCGA-DY-A0XA.h5
# Writing KRAS_binary to TCGA-DY-A1DC.h5
# Writing KRAS_binary to TCGA-DY-A1DD.h5
# Writing KRAS_binary to TCGA-DY-A1DE.h5
# Writing KRAS_binary to TCGA-DY-A1DF.h5
# Writing KRAS_binary to TCGA-DY-A1DG.h5
# Writing KRAS_binary to TCGA-EF-5830.h5
# Writing KRAS_binary to TCGA-EI-6506.h5
# Writing KRAS_binary to TCGA-EI-6507.h5
# Writing KRAS_binary to TCGA-EI-6882.h5
# Writing KRAS_binary to TCGA-EI-6883.h5
# Writing KRAS_binary to TCGA-EI-6884.h5
# Writing KRAS_binary to TCGA-EI-6885.h5
# Writing KRAS_binary to TCGA-EI-6917.h5
# Writing KRAS_binary to TCGA-EI-7002.h5
# Writing KRAS_binary to TCGA-EI-7004.h5
# Writing KRAS_binary to TCGA-F4-6459.h5
# Writing KRAS_binary to TCGA-F4-6460.h5
# Writing KRAS_binary to TCGA-F4-6461.h5
# Writing KRAS_binary to TCGA-F4-6463.h5
# Writing KRAS_binary to TCGA-F4-6569.h5
# Writing KRAS_binary to TCGA-F4-6570.h5
# Writing KRAS_binary to TCGA-F4-6703.h5
# Writing KRAS_binary to TCGA-F4-6704.h5
# Writing KRAS_binary to TCGA-F4-6805.h5
# Writing KRAS_binary to TCGA-F4-6806.h5
# Writing KRAS_binary to TCGA-F4-6807.h5
# Writing KRAS_binary to TCGA-F4-6808.h5
# Writing KRAS_binary to TCGA-F4-6809.h5
# Writing KRAS_binary to TCGA-F4-6854.h5
# Writing KRAS_binary to TCGA-F4-6855.h5
# Writing KRAS_binary to TCGA-F4-6856.h5
# Writing KRAS_binary to TCGA-F5-6464.h5
# Writing KRAS_binary to TCGA-F5-6465.h5
# Writing KRAS_binary to TCGA-F5-6571.h5
# Writing KRAS_binary to TCGA-F5-6702.h5
# Writing KRAS_binary to TCGA-F5-6810.h5
# Writing KRAS_binary to TCGA-F5-6811.h5
# Writing KRAS_binary to TCGA-F5-6812.h5
# Writing KRAS_binary to TCGA-F5-6813.h5
# Writing KRAS_binary to TCGA-F5-6814.h5
# Writing KRAS_binary to TCGA-F5-6863.h5
# Writing KRAS_binary to TCGA-F5-6864.h5
# Writing KRAS_binary to TCGA-G4-6293.h5
# Writing KRAS_binary to TCGA-G4-6294.h5
# Writing KRAS_binary to TCGA-G4-6295.h5
# Writing KRAS_binary to TCGA-G4-6297.h5
# Writing KRAS_binary to TCGA-G4-6298.h5
# Writing KRAS_binary to TCGA-G4-6299.h5
# Writing KRAS_binary to TCGA-G4-6302.h5
# Writing KRAS_binary to TCGA-G4-6303.h5
# Writing KRAS_binary to TCGA-G4-6317.h5
# Writing KRAS_binary to TCGA-G4-6320.h5
# Writing KRAS_binary to TCGA-G4-6321.h5
# Writing KRAS_binary to TCGA-G4-6322.h5
# Writing KRAS_binary to TCGA-G4-6323.h5
# Writing KRAS_binary to TCGA-G4-6586.h5
# Writing KRAS_binary to TCGA-G4-6588.h5
# Writing KRAS_binary to TCGA-G4-6625.h5
# Writing KRAS_binary to TCGA-G4-6626.h5
# Writing KRAS_binary to TCGA-G4-6627.h5
# Writing KRAS_binary to TCGA-G4-6628.h5
# Writing KRAS_binary to TCGA-G5-6233.h5
# Writing KRAS_binary to TCGA-G5-6235.h5
# Writing KRAS_binary to TCGA-G5-6572.h5
# Writing KRAS_binary to TCGA-G5-6641.h5
# Writing KRAS_binary to TCGA-NH-A50T.h5
# Writing KRAS_binary to TCGA-NH-A50U.h5
# Writing KRAS_binary to TCGA-NH-A50V.h5
# Writing KRAS_binary to TCGA-NH-A5IV.h5
# Writing KRAS_binary to TCGA-NH-A6GA.h5
# Writing KRAS_binary to TCGA-NH-A6GB.h5
# Writing KRAS_binary to TCGA-NH-A6GC.h5
# Writing KRAS_binary to TCGA-NH-A8F7.h5
# Writing KRAS_binary to TCGA-NH-A8F8.h5
# Writing KRAS_binary to TCGA-QG-A5YV.h5
# Writing KRAS_binary to TCGA-QG-A5YW.h5
# Writing KRAS_binary to TCGA-QG-A5YX.h5
# Writing KRAS_binary to TCGA-QG-A5Z1.h5
# Writing KRAS_binary to TCGA-QG-A5Z2.h5
# Writing KRAS_binary to TCGA-QL-A97D.h5
# Writing KRAS_binary to TCGA-SS-A7HO.h5
# Writing KRAS_binary to TCGA-T9-A92H.h5
# Writing KRAS_binary to TCGA-WS-AB45.h5

# %%
print(matched.keys())
display(matched)
# Out:
# Index(['h5_path', 'Sample_ID', 'index', 'KRAS', 'KRAS_binary'], dtype='object')
#                                                h5_path     Sample_ID  index  \
# 0    /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-3L-AA1B      0
# 1    /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4N-A93T      1
# 2    /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-4T-AA8H      2
# 3    /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT4      3
# 4    /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-5M-AAT5      4
# ..                                                 ...           ...    ...
# 488  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-QG-A5Z2    634
# 489  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-QL-A97D    635
# 490  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-SS-A7HO    637
# 491  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-T9-A92H    638
# 492  /orcd/data/edboyden/002/ezh/uni/virchow_featur...  TCGA-WS-AB45    639
#
#      KRAS  KRAS_binary
# 0      WT          0.0
# 1    G12D          1.0
# 2    G12V          1.0
# 3    G12D          1.0
# 4    G12D          1.0
# ..    ...          ...
# 488    WT          0.0
# 489  G12D          1.0
# 490  G12A          1.0
# 491    WT          0.0
# 492    WT          0.0
#
# [490 rows x 5 columns]

# %% [markdown]
# ## Do some sanity checking

# %% [markdown]
# Print how many H5 files exist vs. how many have the label

# %%
import h5py
import os

dir_path = "/orcd/data/edboyden/002/ezh/uni/virchow_features"
label_name = "KRAS_binary"

total_files = 0
files_with_label = 0
label_counts = {}
missing_label_files = []

for fname in os.listdir(dir_path):
    if not fname.endswith(".h5"):
        continue
    total_files += 1
    fpath = os.path.join(dir_path, fname)
    try:
        with h5py.File(fpath, "r") as f:
            if label_name in f:
                label = int(f[label_name][()])
                files_with_label += 1
                label_counts[label] = label_counts.get(label, 0) + 1
            else:
                missing_label_files.append(fname)
    except Exception as e:
        print(f"Error reading {fname}: {e}")

print("Total .h5 files:", total_files)
print(f"Files with label '{label_name}':", files_with_label)
print("Label distribution:", label_counts)
print("Files missing the label (first 5):", missing_label_files[:5])
# Out:
# Total .h5 files: 493
# Files with label 'KRAS_binary': 490
# Label distribution: {0: 295, 1: 195}
# Files missing the label (first 5): ['TCGA-AA-3970.h5', 'TCGA-A6-6140.h5', 'TCGA-A6-6141.h5']
