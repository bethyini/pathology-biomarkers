# %% [markdown]
# ## Look at the h5 files

# %%
# %pwd
# Out:
# '/orcd/data/edboyden/002/ezh/uni'

# %%
import h5py

with h5py.File("virchow_features/TCGA-A6-2672.h5", "r") as f:
    print(list(f.keys()))
    print(f["features"].shape)  # (N_patches, 1536)
    if "KRAS_binary" in f:
        print(f["KRAS_binary"][()])
# Out:
# ['Lymphovascular invasion indicator', 'coords', 'features']
# (3102, 2560)

# %%
import h5py
import os
from glob import glob

# Set the directory where the .h5 files are located
h5_folder = "CLAM/TCGA-COAD/"  # 🔁 Replace with your actual path
h5_paths = sorted(glob(os.path.join(h5_folder, "**/*.h5"), recursive=True))

# Track patch counts
patch_counts = []

for path in h5_paths:
    try:
        with h5py.File(path, "r") as f:
            # Try "features" key first
            data = f["features"][:]
            # Squeeze if necessary
            if data.ndim == 3:
                data = data[0]
            patch_counts.append((os.path.basename(path), data.shape[0]))
    except Exception as e:
        patch_counts.append((os.path.basename(path), f"Error: {e}"))

# Convert to DataFrame for display
import pandas as pd
import ace_tools as tools

patch_df = pd.DataFrame(patch_counts, columns=["File", "Num_Patches"])
tools.display_dataframe_to_user(name="Patch Count per Slide", dataframe=patch_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 16
#      13 try:
#      14     with h5py.File(path, "r") as f:
#      15         # Try "features" key first
# ---> 16         data = f["features"][:]
#      17         # Squeeze if necessary
#      18         if data.ndim == 3:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/h5py/_hl/dataset.py:741, in Dataset.__getitem__(self, args, new_dtype)
#     739 if self._fast_read_ok and (new_dtype is None):
#     740     try:
# --> 741         return self._fast_reader.read(args)
#     742     except TypeError:
#     743         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %% [markdown]
# Search for nonzero annotations in all the h5 files

# %%
import os
from glob import glob

def has_nonzero_annots(h5_path):
    with h5py.File(h5_path, "r") as f:
        if "annots" in f:
            annots = f["annots"][:]
            return np.any(annots != 0)
    return False

folder = "/UNI2-h_features/TCGA-COAD/"
paths = sorted(glob(os.path.join(folder, "**/*.h5"), recursive=True))

nonzero_annot_slides = [p for p in paths if has_nonzero_annots(p)]

print(f"Found {len(nonzero_annot_slides)} slides with non-zero annotations.")
for path in nonzero_annot_slides:
    print("found", os.path.basename(path))
# Out:
# Found 0 slides with non-zero annotations.

# %% [markdown]
# ## Look at TSV file downloaded from CBioPortal for COAD-Read

# %%
import pandas as pd
import pprint as pp

clinical_path = "all_tcga_datasets.tsv"  # or full path if not in current dir
df = pd.read_csv(clinical_path, sep="\t")

print("Loaded TSV file with shape:", df.shape)
# print("\nColumn names:")
display(df.columns.tolist())
# Out:
# Loaded TSV file with shape: (640, 145)
# ['Study ID',
#  'Patient ID',
#  'Sample ID',
#  'Diagnosis Age',
#  'American Joint Committee on Cancer Publication Version Type',
#  'Biopsy Site',
#  'Cancer Type',
#  'Cancer Type Detailed',
#  'Disease Free (Months)',
#  'Disease Free Status',
#  'Disease Type',
#  'Ethnicity Category',
#  'Fraction Genome Altered',
#  'ICD-10 Classification',
#  'Is FFPE',
#  'Morphology',
#  'Mutation Count',
#  'Oncotree Code',
#  'Overall Survival (Months)',
#  'Overall Survival Status',
#  'Other Patient ID',
#  'Other Sample ID',
#  'AJCC Pathologic M-Stage',
#  'AJCC Pathologic N-Stage',
#  'AJCC Pathologic Stage',
#  'AJCC Pathologic T-Stage',
#  'Primary Diagnosis',
#  'Patient Primary Tumor Site',
#  'Prior Malignancy',
#  'Prior Treatment',
#  'Project Identifier',
#  'Project Name',
#  'Project State',
#  'Race Category',
#  'Number of Samples Per Patient',
#  'Sample Type',
#  'Sex',
#  "Patient's Vital Status",
#  'Year of Death',
#  'Year of Diagnosis',
#  'American Joint Committee on Cancer Metastasis Stage Code',
#  'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code',
#  'Neoplasm Disease Stage American Joint Committee on Cancer Code',
#  'American Joint Committee on Cancer Tumor Stage Code',
#  'BRAF Gene Analysis Indicator',
#  'BRAF Gene Analysis Result',
#  'Neoplasm American Joint Committee on Cancer Clinical Distant Metastasis M Stage',
#  'Neoplasm American Joint Committee on Cancer Clinical Regional Lymph Node N Stage',
#  'Neoplasm American Joint Committee on Cancer Clinical Primary Tumor T Stage',
#  'Neoplasm American Joint Committee on Cancer Clinical Group Stage',
#  'Days to Sample Collection.',
#  'Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value',
#  'days_to_patient_progression_free',
#  'Days to Sample Procurement',
#  'days_to_tumor_progression',
#  'Disease code',
#  'Lymphomatous Extranodal Site Involvement Indicator',
#  'Form completion date',
#  'Patient Height',
#  'Neoplasm Histologic Type Name',
#  'Neoadjuvant Therapy Type Administered Prior To Resection Text',
#  'Prior Cancer Diagnosis Occurence',
#  'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code',
#  'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code',
#  'Informed consent verified',
#  'Initial pathologic diagnosis method',
#  'Year Cancer Initial Diagnosis',
#  'Kras gene analysis indicator',
#  'KRAS Mutation',
#  'Longest Dimension',
#  'Lymph Node(s) Examined Number',
#  'Primary Lymph Node Presentation Assessment Ind-3',
#  'Positive Finding Lymph Node Hematoxylin and Eosin Staining Microscopy Count',
#  'Positive Finding Lymph Node Keratin Immunohistochemistry Staining Method Count',
#  'Lymphovascular invasion indicator',
#  'First Pathologic Diagnosis Biospecimen Acquisition Method Type',
#  'New Neoplasm Event Post Initial Therapy Indicator',
#  'Oct embedded',
#  'Specimen Collection Method',
#  'Pathology Report File Name',
#  'Pathology report uuid',
#  'Perineural Invasion',
#  'Adjuvant Postoperative Pharmaceutical Therapy Administered Indicator',
#  'Project code',
#  'Tissue Prospective Collection Indicator',
#  'Did patient start adjuvant postoperative radiotherapy?',
#  'Surgical Margin Resection Status',
#  'Tissue Retrospective Collection Indicator',
#  'Sample Initial Weight',
#  'Sample type id',
#  'Shortest Dimension',
#  'Tumor Tissue Site',
#  'Somatic Status',
#  'Specimen Current Weight',
#  'Specimen Freezing Means',
#  'Specimen Second Longest Dimension',
#  'Stage Other',
#  'Time between clamping and freezing',
#  'Time between excision and freezing',
#  'Tissue Source Site',
#  'TMB (nonsynonymous)',
#  'Primary Therapy Outcome Success Type',
#  'Person Neoplasm Status',
#  'Vascular invasion indicator',
#  'Vial number',
#  'Patient Weight',
#  'Aneuploidy Score',
#  'Buffa Hypoxia Score',
#  'TCGA PanCanAtlas Cancer Type Acronym',
#  'Last Communication Contact from Initial Pathologic Diagnosis Date',
#  'Birth from Initial Pathologic Diagnosis Date',
#  'Months of disease-specific survival',
#  'Disease-specific Survival status',
#  'Genetic Ancestry Label',
#  'Neoplasm Histologic Grade',
#  'In PanCan Pathway Analysis',
#  'MSI MANTIS Score',
#  'MSIsensor Score',
#  'Person Neoplasm Cancer Status',
#  'Progress Free Survival (Months)',
#  'Progression Free Status',
#  'Primary Lymph Node Presentation Assessment',
#  'Prior Diagnosis',
#  'Radiation Therapy',
#  'Ragnum Hypoxia Score',
#  'Subtype',
#  'Tumor Break Load',
#  'Tissue Source Site Code',
#  'Tumor Disease Anatomic Site',
#  'Tumor Type',
#  'Winter Hypoxia Score',
#  'Copy Number',
#  'Gene Expression Subtype',
#  'Tumor Other Histologic Subtype',
#  'Hyper-mutated',
#  'iCluster',
#  'Methylation Status',
#  'Methylation Subtype',
#  'MLH1 Silencing',
#  'MRNA Data',
#  'MSI Status',
#  'Primary Tumor Site',
#  'Primary Tumor Pathologic Spread',
#  'Sequenced',
#  'Tumor Stage 2009']

# %%
display(df['KRAS Mutation'])
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 635    NaN
# 636    NaN
# 637    NaN
# 638    NaN
# 639    YES
# Name: KRAS Mutation, Length: 640, dtype: object

# %%
# look at KRAS mutation column
if 'KRAS Mutation' in df.columns:
    print("\nKRAS Mutation Value Counts:")
    print(df['KRAS Mutation'].value_counts(dropna=False))
else:
    print("\n'KRAS Mutation' column not found in file.")
# Out:
# KRAS Mutation Value Counts:
# NaN    623
# YES     10
# NO       7
# Name: KRAS Mutation, dtype: int64

# %% [markdown]
# ## Look at data that might contain MMR status

# %%
import pandas as pd

# Step 1: Load the wide format TSV file
mmr_path = "Human__TCGA_COADREAD__MS__Clinical__Clinical__01_28_2016__BI__Clinical__Firehose.tsi.txt"
mmr_df = pd.read_csv(mmr_path, sep="\t", index_col=0)

# Step 2: Transpose so each row is a sample (patient), each column an attribute
mmr_df = mmr_df.T
mmr_df.index.name = "Sample_ID"

# Step 3: Preview
display(mmr_df.shape)
display(mmr_df.columns.tolist())  # column names like 'Mutation_Phenotype'
display(mmr_df.head(20))  # first 3 samples
# Out:
# (629, 17)
# ['years_to_birth',
#  'Tumor_purity',
#  'pathologic_stage',
#  'pathology_T_stage',
#  'pathology_N_stage',
#  'pathology_M_stage',
#  'histological_type',
#  'number_of_lymph_nodes',
#  'Proteomic.subtype',
#  'gender',
#  'radiation_therapy',
#  'residual_tumor',
#  'ethnicity',
#  'MSI_phenotype',
#  'overall_survival',
#  'status',
#  'overallsurvival']
# attrib_name  years_to_birth Tumor_purity pathologic_stage pathology_T_stage  \
# Sample_ID
# TCGA.A6.2677             68       0.8869         stageiii                t3
# TCGA.A6.2681             73       0.6939          stageii                t3
# TCGA.A6.2682             70       0.7927          stageiv                t4
# TCGA.A6.4105             79       0.7533          stageii                t3
# TCGA.A6.6649             66       0.7857         stageiii                t3
# TCGA.AA.3496             83       0.7004          stageii                t3
# TCGA.AA.3506             77       0.7979           stagei                t2
# TCGA.AA.3516             74       0.6843         stageiii                t3
# TCGA.AA.3520             86       0.7372          stageii                t3
# TCGA.AA.3521             87       0.8137          stageii                t3
# TCGA.AA.3522             67       0.6299          stageii                t3
# TCGA.AA.3524             85       0.8229          stageii                t3
# TCGA.AA.3525             89       0.7697         stageiii                t3
# TCGA.AA.3527             89       0.8374          stageii                t3
# TCGA.AA.3530             80       0.8619           stagei                t2
# TCGA.AA.3531             75        0.722          stageii                t3
# TCGA.AA.3543             84        0.809           stagei                t2
# TCGA.AA.3552             85       0.7236         stageiii                t3
# TCGA.AA.3554             62       0.5327          stageii                t3
# TCGA.AA.3556             78       0.8469           stagei                t2
#
# attrib_name  pathology_N_stage pathology_M_stage            histological_type  \
# Sample_ID
# TCGA.A6.2677                n2                m0          colonadenocarcinoma
# TCGA.A6.2681                n0                m0          colonadenocarcinoma
# TCGA.A6.2682                n1                m1          colonadenocarcinoma
# TCGA.A6.4105                n0                m0          colonadenocarcinoma
# TCGA.A6.6649                n1                m0          colonadenocarcinoma
# TCGA.AA.3496                n0                m0          colonadenocarcinoma
# TCGA.AA.3506                n0                m0          colonadenocarcinoma
# TCGA.AA.3516                n2                m0  colonmucinousadenocarcinoma
# TCGA.AA.3520                n0                m0          colonadenocarcinoma
# TCGA.AA.3521                n0                m0          colonadenocarcinoma
# TCGA.AA.3522                n0                m0          colonadenocarcinoma
# TCGA.AA.3524                n0                m0          colonadenocarcinoma
# TCGA.AA.3525                n1                m0          colonadenocarcinoma
# TCGA.AA.3527                n0                m0          colonadenocarcinoma
# TCGA.AA.3530                n0                m0          colonadenocarcinoma
# TCGA.AA.3531                n0                m0          colonadenocarcinoma
# TCGA.AA.3543                n0                m0  colonmucinousadenocarcinoma
# TCGA.AA.3552                n2                m0          colonadenocarcinoma
# TCGA.AA.3554                n0                m0          colonadenocarcinoma
# TCGA.AA.3556                n0                m0                          NaN
#
# attrib_name  number_of_lymph_nodes Proteomic.subtype  gender  \
# Sample_ID
# TCGA.A6.2677                     5               NaN  female
# TCGA.A6.2681                     0               NaN  female
# TCGA.A6.2682                     2               NaN    male
# TCGA.A6.4105                     0               NaN    male
# TCGA.A6.6649                     2               NaN    male
# TCGA.AA.3496                     0               NaN  female
# TCGA.AA.3506                     0               NaN    male
# TCGA.AA.3516                     7               NaN  female
# TCGA.AA.3520                     0               NaN  female
# TCGA.AA.3521                     0               NaN    male
# TCGA.AA.3522                     0               NaN    male
# TCGA.AA.3524                     0               NaN    male
# TCGA.AA.3525                     2                 B    male
# TCGA.AA.3527                     0               NaN  female
# TCGA.AA.3530                     0               NaN    male
# TCGA.AA.3531                     0                 A  female
# TCGA.AA.3543                     0               NaN    male
# TCGA.AA.3552                    10                 D    male
# TCGA.AA.3554                     0                 C  female
# TCGA.AA.3556                     0               NaN    male
#
# attrib_name  radiation_therapy residual_tumor            ethnicity  \
# Sample_ID
# TCGA.A6.2677                no             r0  nothispanicorlatino
# TCGA.A6.2681                no             r0  nothispanicorlatino
# TCGA.A6.2682                no             r0  nothispanicorlatino
# TCGA.A6.4105                no            NaN  nothispanicorlatino
# TCGA.A6.6649                no            NaN  nothispanicorlatino
# TCGA.AA.3496               NaN             r0                  NaN
# TCGA.AA.3506                no             r0                  NaN
# TCGA.AA.3516                no            NaN                  NaN
# TCGA.AA.3520                no             r0                  NaN
# TCGA.AA.3521               NaN             r0                  NaN
# TCGA.AA.3522                no             r0                  NaN
# TCGA.AA.3524                no             r0                  NaN
# TCGA.AA.3525                no             r0                  NaN
# TCGA.AA.3527               NaN             r0                  NaN
# TCGA.AA.3530                no             r0                  NaN
# TCGA.AA.3531                no             r0                  NaN
# TCGA.AA.3543                no             r0                  NaN
# TCGA.AA.3552                no             r0                  NaN
# TCGA.AA.3554                no             r0                  NaN
# TCGA.AA.3556                no             r0                  NaN
#
# attrib_name  MSI_phenotype overall_survival status overallsurvival
# Sample_ID
# TCGA.A6.2677           MSS              740      1           740,1
# TCGA.A6.2681           MSS             1387      0          1387,0
# TCGA.A6.2682           MSS              424      1           424,1
# TCGA.A6.4105           MSS              442      1           442,1
# TCGA.A6.6649           MSS              735      0           735,0
# TCGA.AA.3496           MSS               31      0            31,0
# TCGA.AA.3506           MSS             1765      0          1765,0
# TCGA.AA.3516         MSI-H              396      1           396,1
# TCGA.AA.3520           MSS              731      0           731,0
# TCGA.AA.3521           MSS              NaN    NaN           NA,NA
# TCGA.AA.3522           MSS             1127      0          1127,0
# TCGA.AA.3524           MSS             1096      0          1096,0
# TCGA.AA.3525         MSI-H              245      0           245,0
# TCGA.AA.3527           MSS              NaN    NaN           NA,NA
# TCGA.AA.3530           MSS              580      0           580,0
# TCGA.AA.3531           MSS             1035      0          1035,0
# TCGA.AA.3543         MSI-H               30      0            30,0
# TCGA.AA.3552           MSS              396      1           396,1
# TCGA.AA.3554         MSI-H              546      0           546,0
# TCGA.AA.3556           MSS              700      0           700,0

# %%
print(mmr_df["MSI_phenotype"].value_counts(dropna=False))

# Map MSI-H to 1 (dMMR), MSS to 0 (pMMR)
mmr_df["MMR_status"] = mmr_df["MSI_phenotype"].map({
    "MSI-H": 1,          # dMMR
    "MSS": 0,            # pMMR
})


# Drop any samples with NA
mmr_df = mmr_df.dropna(subset=["MMR_status"])

# Check label distribution
print(mmr_df["MMR_status"].value_counts())



# display(mmr_df["MMR_status"])
# Out:
# MSS      537
# MSI-H     89
# Name: MSI_phenotype, dtype: int64
# 0    537
# 1     89
# Name: MMR_status, dtype: int64

# %% [markdown]
# ## Match each h5 file to label

# %%
import pandas as pd

# Load the file
mutation_df = pd.read_csv('lymphovascular_invasion.csv')

display(mutation_df.head(10))
# Out:
#       Sample_ID  Lymphovascular invasion indicator
# 0  TCGA-3L-AA1B                                0.0
# 1  TCGA-4N-A93T                                0.0
# 2  TCGA-4T-AA8H                                0.0
# 3  TCGA-5M-AAT4                                NaN
# 4  TCGA-5M-AAT5                                NaN
# 5  TCGA-5M-AAT6                                1.0
# 6  TCGA-5M-AATA                                NaN
# 7  TCGA-5M-AATE                                0.0
# 8  TCGA-A6-2670                                0.0
# 9  TCGA-A6-2671                                1.0

# %%
import os
import pandas as pd
from glob import glob

# %%
h5_folder = "virchow_features"
mutation = "Lymphovascular invasion indicator"
h5_paths = sorted(glob(os.path.join(h5_folder, "*.h5")))
print(f"\nFound {len(h5_paths)} .h5 files")
# Out:
# Found 493 .h5 files

# %%
# Extract TCGA ID from each .h5 filename
def extract_tcga_id(path):
    basename = os.path.basename(path)
    return "-".join(basename.split("-")[:3])  # TCGA-XX-YYYY

h5_df = pd.DataFrame({
    "h5_path": h5_paths,
    "Sample_ID": [extract_tcga_id(p) for p in h5_paths]
})

h5_df['Sample_ID'] = h5_df['Sample_ID'].str.replace('.h5', '')

print("\nFirst 5 extracted TCGA IDs:")
print(h5_df.head())
# Out:
# First 5 extracted TCGA IDs:
#                             h5_path     Sample_ID
# 0  virchow_features/TCGA-3L-AA1B.h5  TCGA-3L-AA1B
# 1  virchow_features/TCGA-4N-A93T.h5  TCGA-4N-A93T
# 2  virchow_features/TCGA-4T-AA8H.h5  TCGA-4T-AA8H
# 3  virchow_features/TCGA-5M-AAT4.h5  TCGA-5M-AAT4
# 4  virchow_features/TCGA-5M-AAT5.h5  TCGA-5M-AAT5
# /tmp/ipykernel_510306/3986256730.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   h5_df['Sample_ID'] = h5_df['Sample_ID'].str.replace('.h5', '')

# %%
print("\nSample_ID format in mutation_df:")
print(mutation_df['Sample_ID'].head())

print("\nSample_ID format in h5_df:")
print(h5_df['Sample_ID'].head())
# Out:
# Sample_ID format in mutation_df:
# 0    TCGA-3L-AA1B
# 1    TCGA-4N-A93T
# 2    TCGA-4T-AA8H
# 3    TCGA-5M-AAT4
# 4    TCGA-5M-AAT5
# Name: Sample_ID, dtype: object
#
# Sample_ID format in h5_df:
# 0    TCGA-3L-AA1B
# 1    TCGA-4N-A93T
# 2    TCGA-4T-AA8H
# 3    TCGA-5M-AAT4
# 4    TCGA-5M-AAT5
# Name: Sample_ID, dtype: object

# %%
merged_df = h5_df.merge(mutation_df, on="Sample_ID", how="left")

display(merged_df.head(10))

# Separate matched/unmatched again
matched = merged_df.dropna(subset=[mutation])
unmatched = merged_df[merged_df[mutation].isna()]

# Print results
print(f"\nMatched: {len(matched)}")
print(f"Unmatched: {len(unmatched)}")
print("\nMatched sample preview:")
print(matched[["Sample_ID", mutation]].head(5))
# Out:
#                             h5_path     Sample_ID  \
# 0  virchow_features/TCGA-3L-AA1B.h5  TCGA-3L-AA1B
# 1  virchow_features/TCGA-4N-A93T.h5  TCGA-4N-A93T
# 2  virchow_features/TCGA-4T-AA8H.h5  TCGA-4T-AA8H
# 3  virchow_features/TCGA-5M-AAT4.h5  TCGA-5M-AAT4
# 4  virchow_features/TCGA-5M-AAT5.h5  TCGA-5M-AAT5
# 5  virchow_features/TCGA-5M-AAT6.h5  TCGA-5M-AAT6
# 6  virchow_features/TCGA-5M-AATE.h5  TCGA-5M-AATE
# 7  virchow_features/TCGA-A6-2671.h5  TCGA-A6-2671
# 8  virchow_features/TCGA-A6-2672.h5  TCGA-A6-2672
# 9  virchow_features/TCGA-A6-2674.h5  TCGA-A6-2674
#
#    Lymphovascular invasion indicator
# 0                                0.0
# 1                                0.0
# 2                                0.0
# 3                                NaN
# 4                                NaN
# 5                                1.0
# 6                                0.0
# 7                                1.0
# 8                                1.0
# 9                                0.0
# Matched: 456
# Unmatched: 37
#
# Matched sample preview:
#       Sample_ID  Lymphovascular invasion indicator
# 0  TCGA-3L-AA1B                                0.0
# 1  TCGA-4N-A93T                                0.0
# 2  TCGA-4T-AA8H                                0.0
# 5  TCGA-5M-AAT6                                1.0
# 6  TCGA-5M-AATE                                0.0

# %%
print(matched[mutation].value_counts())
# Out:
# 0.0    281
# 1.0    175
# Name: Lymphovascular invasion indicator, dtype: int64

# %% [markdown]
# ### Save the mutation status column in the h5 file

# %%
import h5py

# Loop over matched rows
for idx, row in matched.iterrows():
    h5_path = row["h5_path"]
    label = int(row[mutation])  # make sure it's a simple 0 or 1
    
    try:
        with h5py.File(h5_path, "a") as f:  # 'a' = append mode
            if mutation in f:
                print(f"Overwriting existing {mutation} in {os.path.basename(h5_path)}")
                del f[mutation]
            else:
                print(f"Writing {mutation} to {os.path.basename(h5_path)}")
            
            f.create_dataset(mutation, data=label)
    
    except Exception as e:
        print(f"Error writing to {h5_path}: {e}")
# Out:
# Writing Lymphovascular invasion indicator to TCGA-3L-AA1B.h5
# Writing Lymphovascular invasion indicator to TCGA-4N-A93T.h5
# Writing Lymphovascular invasion indicator to TCGA-4T-AA8H.h5
# Writing Lymphovascular invasion indicator to TCGA-5M-AAT6.h5
# Writing Lymphovascular invasion indicator to TCGA-5M-AATE.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2671.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2672.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2674.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2675.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2676.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2677.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2678.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2679.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2680.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2681.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2682.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2683.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2684.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2685.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-2686.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-3807.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-3808.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-3809.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-3810.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-4105.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-4107.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5656.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5657.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5659.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5660.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5661.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5662.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5664.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5665.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5666.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-5667.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6137.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6138.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6140.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6141.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6142.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6648.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6649.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6650.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6651.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6652.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6653.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-6654.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-A565.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-A566.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-A567.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-A56B.h5
# Writing Lymphovascular invasion indicator to TCGA-A6-A5ZU.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3492.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3509.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3510.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3511.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3514.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3516.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3517.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3518.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3519.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3520.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3521.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3522.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3524.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3525.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3526.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3527.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3529.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3530.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3531.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3532.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3534.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3538.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3542.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3543.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3544.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3548.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3549.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3552.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3553.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3554.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3555.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3556.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3558.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3560.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3561.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3562.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3655.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3660.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3662.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3663.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3664.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3666.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3667.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3672.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3673.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3675.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3678.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3679.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3680.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3681.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3684.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3685.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3688.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3692.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3693.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3695.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3696.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3710.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3712.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3715.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3811.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3812.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3814.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3815.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3818.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3819.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3831.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3833.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3837.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3841.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3842.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3844.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3845.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3846.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3848.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3850.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3851.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3852.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3854.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3855.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3856.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3858.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3860.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3861.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3862.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3864.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3866.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3867.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3869.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3870.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3872.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3875.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3877.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3930.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3939.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3941.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3947.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3949.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3950.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3952.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3955.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3956.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3966.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3967.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3968.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3970.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3971.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3972.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3973.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3975.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3977.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3979.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3980.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3982.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3984.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3986.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3989.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-3994.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A004.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00A.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00D.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00E.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00F.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00J.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00K.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00L.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00N.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00O.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00Q.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00R.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00U.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00W.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A00Z.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A010.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A017.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01C.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01D.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01F.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01G.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01I.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01K.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01P.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01Q.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01R.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01T.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01X.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A01Z.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A022.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02E.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02F.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02H.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02J.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02K.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02O.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02R.h5
# Writing Lymphovascular invasion indicator to TCGA-AA-A02Y.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-5900.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6548.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6888.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6889.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6890.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6895.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6899.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6901.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6963.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6964.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-6965.h5
# Writing Lymphovascular invasion indicator to TCGA-AD-A5EJ.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-2687.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-2690.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-2693.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-3911.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-4110.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-5654.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-6136.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-6655.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-6672.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-A56K.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-A56L.h5
# Writing Lymphovascular invasion indicator to TCGA-AF-A56N.h5
# Writing Lymphovascular invasion indicator to TCGA-AG-3591.h5
# Writing Lymphovascular invasion indicator to TCGA-AG-3592.h5
# Writing Lymphovascular invasion indicator to TCGA-AG-3725.h5
# Writing Lymphovascular invasion indicator to TCGA-AG-3732.h5
# Writing Lymphovascular invasion indicator to TCGA-AG-3902.h5
# Writing Lymphovascular invasion indicator to TCGA-AG
h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6322.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6323.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6586.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6588.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6625.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6626.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6627.h5
# Writing Lymphovascular invasion indicator to TCGA-G4-6628.h5
# Writing Lymphovascular invasion indicator to TCGA-G5-6233.h5
# Writing Lymphovascular invasion indicator to TCGA-G5-6235.h5
# Writing Lymphovascular invasion indicator to TCGA-G5-6572.h5
# Writing Lymphovascular invasion indicator to TCGA-G5-6641.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A50T.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A50U.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A50V.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A5IV.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A6GA.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A6GB.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A6GC.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A8F7.h5
# Writing Lymphovascular invasion indicator to TCGA-NH-A8F8.h5
# Writing Lymphovascular invasion indicator to TCGA-QG-A5YV.h5
# Writing Lymphovascular invasion indicator to TCGA-QG-A5YW.h5
# Writing Lymphovascular invasion indicator to TCGA-QG-A5YX.h5
# Writing Lymphovascular invasion indicator to TCGA-QG-A5Z1.h5
# Writing Lymphovascular invasion indicator to TCGA-QG-A5Z2.h5
# Writing Lymphovascular invasion indicator to TCGA-SS-A7HO.h5
# Writing Lymphovascular invasion indicator to TCGA-T9-A92H.h5
# Writing Lymphovascular invasion indicator to TCGA-WS-AB45.h5

# %%
print(matched.keys())
display(matched)
# Out:
# Index(['h5_path', 'Sample_ID', 'Lymphovascular invasion indicator'], dtype='object')
#                               h5_path     Sample_ID  \
# 0    virchow_features/TCGA-3L-AA1B.h5  TCGA-3L-AA1B
# 1    virchow_features/TCGA-4N-A93T.h5  TCGA-4N-A93T
# 2    virchow_features/TCGA-4T-AA8H.h5  TCGA-4T-AA8H
# 5    virchow_features/TCGA-5M-AAT6.h5  TCGA-5M-AAT6
# 6    virchow_features/TCGA-5M-AATE.h5  TCGA-5M-AATE
# ..                                ...           ...
# 487  virchow_features/TCGA-QG-A5Z1.h5  TCGA-QG-A5Z1
# 488  virchow_features/TCGA-QG-A5Z2.h5  TCGA-QG-A5Z2
# 490  virchow_features/TCGA-SS-A7HO.h5  TCGA-SS-A7HO
# 491  virchow_features/TCGA-T9-A92H.h5  TCGA-T9-A92H
# 492  virchow_features/TCGA-WS-AB45.h5  TCGA-WS-AB45
#
#      Lymphovascular invasion indicator
# 0                                  0.0
# 1                                  0.0
# 2                                  0.0
# 5                                  1.0
# 6                                  0.0
# ..                                 ...
# 487                                1.0
# 488                                0.0
# 490                                1.0
# 491                                0.0
# 492                                0.0
#
# [456 rows x 3 columns]

# %%
import h5py
import os
from glob import glob
import pandas as pd

h5_paths = sorted(glob(os.path.join(h5_folder, "*.h5")))

records = []

for path in h5_paths:
    filename = os.path.basename(path)
    sample_id = "-".join(filename.split("-")[:3])  # TCGA-XX-YYYY
    
    try:
        with h5py.File(path, "r") as f:
            if mutation in f:
                mmr = f[mutation][()]
                print(f"{sample_id}, {mmr}")
                records.append((sample_id, mmr, filename))
            else:
                print(f"{sample_id} missing mutation")
                records.append((sample_id, None, filename))
    except Exception as e:
        print(f"Error reading {filename}: {e}")
        records.append((sample_id, None, filename))

mutation_read_df = pd.DataFrame(records, columns=["Sample_ID", mutation, "Filename"])
display(mutation_read_df)
# Out:
# TCGA-3L-AA1B.h5, 0
# TCGA-4N-A93T.h5, 0
# TCGA-4T-AA8H.h5, 0
# TCGA-5M-AAT4.h5 missing mutation
# TCGA-5M-AAT5.h5 missing mutation
# TCGA-AA-3556.h5, 0
# TCGA-AA-3558.h5, 0
# TCGA-AA-3560.h5, 1
# TCGA-AA-3561.h5, 0
# TCGA-AA-3562.h5, 1
# TCGA-AA-3655.h5, 0
# TCGA-AA-3660.h5, 0
# TCGA-AA-3662.h5, 0
# TCGA-AA-3663.h5, 0
# TCGA-AA-3664.h5, 0
# TCGA-AA-3666.h5, 0
# TCGA-AA-3667.h5, 0
# TCGA-AA-3672.h5, 0
# TCGA-AA-3673.h5, 0
# TCGA-AA-3675.h5, 0
# TCGA-AA-3678.h5, 1
# TCGA-AA-3679.h5, 1
# TCGA-AA-3680.h5, 1
# TCGA-AA-3681.h5, 0
# TCGA-AA-3684.h5, 1
# TCGA-AA-3685.h5, 1
# TCGA-AA-3688.h5, 1
# TCGA-AA-3692.h5, 0
# TCGA-AA-3693.h5, 1
# TCGA-AA-3695.h5, 1
# TCGA-AA-3696.h5, 0
# TCGA-AA-3697.h5 missing mutation
# TCGA-AA-3710.h5, 1
# TCGA-AA-3712.h5, 1
# TCGA-AA-3713.h5 missing mutation
# TCGA-AA-3715.h5, 1
# TCGA-AA-3811.h5, 1
# TCGA-AA-3812.h5, 1
# TCGA-AA-3814.h5, 1
# TCGA-AA-3815.h5, 1
# TCGA-AA-3818.h5, 0
# TCGA-AA-3819.h5, 1
# TCGA-AA-3821.h5 missing mutation
# TCGA-AA-3831.h5, 1
# TCGA-AA-3833.h5, 1
# TCGA-AA-3837.h5, 1
# TCGA-AA-3841.h5, 1
# TCGA-AA-3842.h5, 1
# TCGA-AA-3844.h5, 1
# TCGA-AA-3845.h5, 1
# TCGA-AA-3846.h5, 1
# TCGA-AA-3848.h5, 1
# TCGA-AA-3850.h5, 1
# TCGA-AA-3851.h5, 1
# TCGA-AA-3852.h5, 1
# TCGA-AA-3854.h5, 1
# TCGA-AA-3855.h5, 1
# TCGA-AA-3856.h5, 1
# TCGA-AA-3858.h5, 1
# TCGA-AA-3860.h5, 1
# TCGA-AA-3861.h5, 1
# TCGA-AA-3862.h5, 1
# TCGA-AA-3864.h5, 0
# TCGA-AA-3866.h5, 0
# TCGA-AA-3867.h5, 1
# TCGA-AA-3869.h5, 1
# TCGA-AA-3870.h5, 1
# TCGA-AA-3872.h5, 1
# TCGA-AA-3875.h5, 0
# TCGA-AA-3877.h5, 0
# TCGA-AA-3930.h5, 1
# TCGA-AA-3939.h5, 0
# TCGA-AA-3941.h5, 1
# TCGA-AA-3947.h5, 0
# TCGA-AA-3949.h5, 0
# TCGA-AA-3950.h5, 0
# TCGA-AA-3952.h5, 1
# TCGA-AA-3955.h5, 1
# TCGA-AA-3956.h5, 0
# TCGA-AA-3966.h5, 1
# TCGA-AA-3967.h5, 0
# TCGA-AA-3968.h5, 0
# TCGA-AA-3970.h5, 0
# TCGA-AA-3971.h5, 0
# TCGA-AA-3972.h5, 0
# TCGA-AA-3973.h5, 1
# TCGA-AA-3975.h5, 0
# TCGA-AA-3976.h5 missing mutation
# TCGA-AA-3977.h5, 0
# TCGA-AA-3979.h5, 0
# TCGA-AA-3980.h5, 1
# TCGA-AA-3982.h5, 1
# TCGA-AA-3984.h5, 1
# TCGA-AA-3986.h5, 0
# TCGA-AA-3989.h5, 1
# TCGA-AA-3994.h5, 0
# TCGA-AA-A004.h5, 0
# TCGA-AA-A00A.h5, 0
# TCGA-AA-A00D.h5, 0
# TCGA-AA-A00E.h5, 0
# TCGA-AA-A00F.h5, 1
# TCGA-AA-A00J.h5, 1
# TCGA-AA-A00K.h5, 0
# TCGA-AA-A00L.h5, 0
# TCGA-AA-A00N.h5, 1
# TCGA-AA-A00O.h5, 1
# TCGA-AA-A00Q.h5, 1
# TCGA-AA-A00R.h5, 0
# TCGA-AA-A00U.h5, 0
# TCGA-AA-A00W.h5, 0
# TCGA-AA-A00Z.h5, 1
# TCGA-AA-A010.h5, 0
# TCGA-AA-A017.h5, 1
# TCGA-AA-A01C.h5, 1
# TCGA-AA-A01D.h5, 1
# TCGA-AA-A01F.h5, 1
# TCGA-AA-A01G.h5, 0
# TCGA-AA-A01I.h5, 0
# TCGA-AA-A01K.h5, 1
# TCGA-AA-A01P.h5, 1
# TCGA-AA-A01Q.h5, 1
# TCGA-AA-A01R.h5, 1
# TCGA-AA-A01S.h5 missing mutation
# TCGA-AA-A01T.h5, 1
# TCGA-AA-A01V.h5 missing mutation
# TCGA-AA-A01X.h5, 1
# TCGA-AA-A01Z.h5, 1
# TCGA-AA-A022.h5, 1
# TCGA-AA-A024.h5 missing mutation
# TCGA-AA-A029.h5 missing mutation
# TCGA-AA-A02E.h5, 1
# TCGA-AA-A02F.h5, 1
# TCGA-AA-A02H.h5, 1
# TCGA-AA-A02J.h5, 1
# TCGA-AA-A02K.h5, 1
# TCGA-AA-A02O.h5, 1
# TCGA-AA-A02R.h5, 1
# TCGA-AA-A02W.h5 missing mutation
# TCGA-AA-A02Y.h5, 1
# TCGA-AA-A03F.h5 missing mutation
# TCGA-AA-A03J.h5 missing mutation
# TCGA-AD-5900.h5, 0
# TCGA-AD-6548.h5, 0
# TCGA-AD-6888.h5, 1
# TCGA-AD-6889.h5, 0
# TCGA-AD-6890.h5, 0
# TCGA-AD-6895.h5, 1
# TCGA-AD-6899.h5, 1
# TCGA-AD-6901.h5, 0
# TCGA-AD-6963.h5, 0
# TCGA-AD-6964.h5, 1
# TCGA-AD-6965.h5, 1
# TCGA-AD-A5EJ.h5, 0
# TCGA-AD-A5EK.h5 missing mutation
# TCGA-AF-2687.h5, 1
# TCGA-AF-2690.h5, 1
# TCGA-AF-2693.h5, 0
# TCGA-AF-3911.h5, 1
# TCGA-AF-4110.h5, 1
# TCGA-AF-5654.h5, 0
# TCGA-AF-6136.h5, 1
# TCGA-AF-6655.h5, 1
# TCGA-AF-6672.h5, 1
# TCGA-AF-A56K.h5, 0
# TCGA-AF-A56L.h5, 1
# TCGA-AF-A56N.h5, 0
# TCGA-AG-3591.h5, 0
# TCGA-AG-3592.h5, 0
# TCGA-AG-3725.h5, 1
# TCGA-AG-3731.h5 missing mutation
# TCGA-AG-3732.h5, 1
# TCGA-AG-3742.h5 missing mutation
# TCGA-AG-3902.h5, 0
# TCGA-AG-4021.h5, 1
# TCGA-AG-4022.h5, 1
# TCGA-D5-6532.h5, 0
# TCGA-D5-6533.h5, 0
# TCGA-D5-6534.h5, 0
# TCGA-D5-6535.h5, 1
# TCGA-D5-6536.h5, 0
# TCGA-D5-6537.h5, 1
# TCGA-D5-6538.h5, 0
# TCGA-D5-6539.h5, 0
# TCGA-D5-6540.h5, 0
# TCGA-D5-6541.h5, 0
# TCGA-D5-6898.h5, 0
# TCGA-D5-6920.h5, 0
# TCGA-D5-6922.h5, 1
# TCGA-D5-6923.h5, 0
# TCGA-D5-6924.h5, 0
# TCGA-D5-6926.h5, 0
# TCGA-D5-6927.h5, 0
# TCGA-D5-6928.h5, 0
# TCGA-D5-6929.h5, 1
# TCGA-D5-6930.h5, 0
# TCGA-D5-6931.h5, 1
# TCGA-D5-6932.h5, 0
# TCGA-D5-7000.h5, 0
# TCGA-DC-4745.h5, 0
# TCGA-DC-4749.h5, 1
# TCGA-DC-5337.h5, 0
# TCGA-DC-5869.h5, 0
# TCGA-DC-6154.h5, 1
# TCGA-DC-6155.h5, 0
# TCGA-DC-6156.h5, 1
# TCGA-DC-6157.h5, 0
# TCGA-DC-6158.h5, 0
# TCGA-DC-6160.h5, 0
# TCGA-DC-6681.h5, 1
# TCGA-DC-6682.h5, 0
# TCGA-DC-6683.h5, 0
# TCGA-DM-A0X9.h5, 0
# TCGA-DM-A0XD.h5, 0
# TCGA-DM-A0XF.h5, 0
# TCGA-DM-A1D0.h5, 0
# TCGA-DM-A1D4.h5, 0
# TCGA-DM-A1D6.h5, 0
# TCGA-DM-A1D7.h5, 0
# TCGA-DM-A1D8.h5 missing mutation
# TCGA-DM-A1D9.h5, 0
# TCGA-DM-A1DA.h5 missing mutation
# TCGA-DM-A1DB.h5, 0
# TCGA-DM-A1HA.h5 missing mutation
# TCGA-DM-A280.h5, 0
# TCGA-DM-A282.h5, 0
# TCGA-DM-A285.h5 missing mutation
# TCGA-DM-A288.h5, 0
# TCGA-DM-A28A.h5, 0
# TCGA-DM-A28E.h5, 0
# TCGA-DM-A28F.h5 missing mutation
# TCGA-DM-A28G.h5, 0
# TCGA-DM-A28H.h5, 0
# TCGA-DM-A28K.h5, 0
# TCGA-DM-A28M.h5, 0
# TCGA-DT-5265.h5 missing mutation
# TCGA-DY-A0XA.h5, 0
# TCGA-DY-A1DC.h5, 0
# TCGA-DY-A1DD.h5 missing mutation
# TCGA-DY-A1DE.h5, 0
# TCGA-DY-A1DF.h5 missing mutation
# TCGA-DY-A1DG.h5 missing mutation
# TCGA-EF-5830.h5, 0
# TCGA-EI-6506.h5, 0
# TCGA-EI-6507.h5, 0
# TCGA-EI-6882.h5, 0
# TCGA-EI-6883.h5, 0
# TCGA-EI-6884.h5, 0
# TCGA-EI-6885.h5, 1
# TCGA-EI-6917.h5, 0
# TCGA-EI-7002.h5, 1
# TCGA-EI-7004.h5, 1
# TCGA-F4-6459.h5, 0
# TCGA-F4-6460.h5, 0
# TCGA-F4-6461.h5, 0
# TCGA-F4-6463.h5, 0
# TCGA-F4-6569.h5, 0
# TCGA-F4-6570.h5, 0
# TCGA-F4-6703.h5, 0
# TCGA-F4-6704.h5, 0
# TCGA-F4-6805.h5, 0
# TCGA-F4-6806.h5, 0
# TCGA-F4-6807.h5, 0
# TCGA-F4-6808.h5, 0
# TCGA-F4-6809.h5, 0
# TCGA-F4-6854.h5, 0
# TCGA-F4-6855.h5, 0
# TCGA-F4-6856.h5, 0
# TCGA-F5-6464.h5, 0
# TCGA-F5-6465.h5, 0
# TCGA-F5-6571.h5, 0
# TCGA-F5-6702.h5, 0
# TCGA-F5-6810.h5 missing mutation
# TCGA-F5-6811.h5, 0
# TCGA-F5-6812.h5, 0
# TCGA-F5-6813.h5, 0
# TCGA-F5-6814.h5, 0
# TCGA-F5-6863.h5, 0
# TCGA-F5-6864.h5, 0
# TCGA-G4-6293.h5, 0
# TCGA-G4-6294.h5, 0
# TCGA-G4-6295.h5, 0
# TCGA-G4-6297.h5, 1
# TCGA-G4-6298.h5, 0
# TCGA-G4-6299.h5, 1
# TCGA-G4-6302.h5, 1
# TCGA-G4-6303.h5, 1
# TCGA-G4-6317.h5 missing mutation
# TCGA-G4-6320.h5, 1
# TCGA-G4-6321.h5, 0
# TCGA-G4-6322.h5, 1
# TCGA-G4-6323.h5, 0
# TCGA-G4-6586.h5, 1
# TCGA-G4-6588.h5, 0
# TCGA-G4-6625.h5, 0
# TCGA-G4-6626.h5, 0
# TCGA-G4-6627.h5, 0
# TCGA-G4-6628.h5, 0
# TCGA-G5-6233.h5, 1
# TCGA-G5-6235.h5, 0
# TCGA-G5-6572.h5, 0
# TCGA-G5-6641.h5, 0
# TCGA-NH-A50T.h5, 0
# TCGA-NH-A50U.h5, 0
# TCGA-NH-A50V.h5, 0
# TCGA-NH-A5IV.h5, 0
# TCGA-NH-A6GA.h5, 1
# TCGA-NH-A6GB.h5, 0
# TCGA-NH-A6GC.h5, 0
# TCGA-NH-A8F7.h5, 0
# TCGA-NH-A8F8.h5, 1
# TCGA-QG-A5YV.h5, 0
# TCGA-QG-A5YW.h5, 0
# TCGA-QG-A5YX.h5, 0
# TCGA-QG-A5Z1.h5, 1
# TCGA-QG-A5Z2.h5, 0
# TCGA-QL-A97D.h5 missing mutation
# TCGA-SS-A7HO.h5, 1
# TCGA-T9-A92H.h5, 0
# TCGA-WS-AB45.h5, 0
#            Sample_ID  Lymphovascular invasion indicator         Filename
# 0    TCGA-3L-AA1B.h5                                0.0  TCGA-3L-AA1B.h5
# 1    TCGA-4N-A93T.h5                                0.0  TCGA-4N-A93T.h5
# 2    TCGA-4T-AA8H.h5                                0.0  TCGA-4T-AA8H.h5
# 3    TCGA-5M-AAT4.h5                                NaN  TCGA-5M-AAT4.h5
# 4    TCGA-5M-AAT5.h5                                NaN  TCGA-5M-AAT5.h5
# ..               ...                                ...              ...
# 488  TCGA-QG-A5Z2.h5                                0.0  TCGA-QG-A5Z2.h5
# 489  TCGA-QL-A97D.h5                                NaN  TCGA-QL-A97D.h5
# 490  TCGA-SS-A7HO.h5                                1.0  TCGA-SS-A7HO.h5
# 491  TCGA-T9-A92H.h5                                0.0  TCGA-T9-A92H.h5
# 492  TCGA-WS-AB45.h5                                0.0  TCGA-WS-AB45.h5
#
# [493 rows x 3 columns]
