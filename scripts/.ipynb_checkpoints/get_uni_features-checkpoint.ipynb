# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.4/481.4 kB 17.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.30.1
#     Uninstalling huggingface-hub-0.30.1:
#       Successfully uninstalled huggingface-hub-0.30.1
# ...

# %%
from huggingface_hub import login


login()

# %%
dataset_name='TCGA'
project_name='TCGA-COAD'

# !huggingface-cli download MahmoodLab/UNI2-h-features TCGA/TCGA-COAD.tar.gz --repo-type dataset --local-dir UNI2-h_features


# !mkdir -p UNI2-h_features/${project_name}
# !tar -xzf UNI2-h_features/${project_name}.tar.gz -C UNI2-h_features/${project_name}
# Out:
# ...
# TCGA-COAD.tar.gz:  15% 2.65G/17.2G [01:06<10:47, 22.5MB/s]
